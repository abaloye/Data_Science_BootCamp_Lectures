# %% [markdown]
# ## Required Reading – Data Cleaning

# %% [markdown]
# #### Checking for Missing Values

# %%
# Import libraries
import pandas as pd
import numpy as np

# %%
# Creating a Data Frame Including NaN
dataset = pd.DataFrame(np.random.randn(5, 3),
index=['a', 'c', 'e', 'f', 'h'],columns=['stock1','stock2', 'stock3'])
dataset.rename(columns={"one":'stock1',"two":'stock2',"three":'stock3'}, inplace=True)
dataset = dataset.reindex(['a', 'b', 'c', 'd', 'e','f', 'g', 'h'])
print (dataset)
# Out:
#      stock1    stock2    stock3
# a  0.073185 -0.979284  1.040710
# b       NaN       NaN       NaN
# c -0.283632  0.921366 -0.584819
# d       NaN       NaN       NaN
# e -0.450377  0.430595 -0.354966
# f -0.713154  0.893242  2.060006
# g       NaN       NaN       NaN
# h -0.294123 -0.103264  1.372476

# %%
# Creating a Matrix of Random Values
import numpy as np
np.random.randn(5, 3)
# Out:
# array([[ 2.87834908e-01,  1.37399806e+00, -6.80537509e-01],
#        [ 3.45500061e-01,  7.74205839e-01, -8.77269847e-01],
#        [-1.21683000e-04, -3.05631113e-01, -4.13923031e-01],
#        [-7.68383290e-01, -2.89154921e-01, -3.47794636e-01],
#        [-1.14131799e+00, -5.68736498e-01, -6.20367375e-01]])

# %%
# Checking Null Cases
print (dataset['stock1'].isnull())
# Out:
# a    False
# b     True
# c    False
# d     True
# e    False
# f    False
# g     True
# h    False
# Name: stock1, dtype: bool

# %% [markdown]
# #### Handling the Missing Values
#  - Replacing NaN with a Scalar Value :

# %%
#  replaces all NaN cases with 0 values
print (dataset)
dataset.fillna(0)
# Out:
#      stock1    stock2    stock3
# a  0.073185 -0.979284  1.040710
# b       NaN       NaN       NaN
# c -0.283632  0.921366 -0.584819
# d       NaN       NaN       NaN
# e -0.450377  0.430595 -0.354966
# f -0.713154  0.893242  2.060006
# g       NaN       NaN       NaN
# h -0.294123 -0.103264  1.372476
#      stock1    stock2    stock3
# a  0.073185 -0.979284  1.040710
# b  0.000000  0.000000  0.000000
# c -0.283632  0.921366 -0.584819
# d  0.000000  0.000000  0.000000
# e -0.450377  0.430595 -0.354966
# f -0.713154  0.893242  2.060006
# g  0.000000  0.000000  0.000000
# h -0.294123 -0.103264  1.372476

# %% [markdown]
# - You can fill NaN cases forward and backward

# %%
# Filling In Missing Values Forward
print (dataset)
dataset.fillna(method='pad')
# Out:
#      stock1    stock2    stock3
# a  0.073185 -0.979284  1.040710
# b       NaN       NaN       NaN
# c -0.283632  0.921366 -0.584819
# d       NaN       NaN       NaN
# e -0.450377  0.430595 -0.354966
# f -0.713154  0.893242  2.060006
# g       NaN       NaN       NaN
# h -0.294123 -0.103264  1.372476
#      stock1    stock2    stock3
# a  0.073185 -0.979284  1.040710
# b  0.073185 -0.979284  1.040710
# c -0.283632  0.921366 -0.584819
# d -0.283632  0.921366 -0.584819
# e -0.450377  0.430595 -0.354966
# f -0.713154  0.893242  2.060006
# g -0.713154  0.893242  2.060006
# h -0.294123 -0.103264  1.372476

# %% [markdown]
# • You can drop the missing values.

# %%
# Dropping All NaN Rows
print (dataset)
dataset.dropna()
# Out:
#      stock1    stock2    stock3
# a  0.073185 -0.979284  1.040710
# b       NaN       NaN       NaN
# c -0.283632  0.921366 -0.584819
# d       NaN       NaN       NaN
# e -0.450377  0.430595 -0.354966
# f -0.713154  0.893242  2.060006
# g       NaN       NaN       NaN
# h -0.294123 -0.103264  1.372476
#      stock1    stock2    stock3
# a  0.073185 -0.979284  1.040710
# c -0.283632  0.921366 -0.584819
# e -0.450377  0.430595 -0.354966
# f -0.713154  0.893242  2.060006
# h -0.294123 -0.103264  1.372476

# %% [markdown]
# • You can replace the missing (or generic) values.

# %%
# Using the replace() Function
print (dataset)
dataset.replace(np.nan, 0 )
# Out:
#      stock1    stock2    stock3
# a  0.073185 -0.979284  1.040710
# b       NaN       NaN       NaN
# c -0.283632  0.921366 -0.584819
# d       NaN       NaN       NaN
# e -0.450377  0.430595 -0.354966
# f -0.713154  0.893242  2.060006
# g       NaN       NaN       NaN
# h -0.294123 -0.103264  1.372476
#      stock1    stock2    stock3
# a  0.073185 -0.979284  1.040710
# b  0.000000  0.000000  0.000000
# c -0.283632  0.921366 -0.584819
# d  0.000000  0.000000  0.000000
# e -0.450377  0.430595 -0.354966
# f -0.713154  0.893242  2.060006
# g  0.000000  0.000000  0.000000
# h -0.294123 -0.103264  1.372476

# %% [markdown]
# ### Reading and Cleaning CSV Data

# %%
# Reading a CSV File and Displaying the First Five Records
import pandas as pd
sales = pd.read_csv("Sales.csv")
print ("\n\n<<<<<<< First 5 records <<<<<<<\n\n" )
print (sales.head())
# Out:
# <<<<<<< First 5 records <<<<<<<
#
#
#    SALES_ID SALES_BY_REGION   JANUARY  FEBRUARY         MARCH     APRIL  \
# 0         1             AUH  3,469.00      n.a.  not avilable  3,642.00
# 1         1             SHJ  5,840.00  5,270.00      4,114.00  5,605.00
# 2         1              -1  2,967.00  2,425.00      5,353.00      n.a.
# 3         2             AUH  1,328.00        -1      1,574.00  2,343.00
# 4         3             SHJ  2,473.00  1,421.00      3,606.00  1,314.00
#
#         MAY      JUNE      JULY    AUGUST SEPTEMBER   OCTOBER  NOVEMBER  \
# 0  5,803.00  5,662.00  1,896.00  2,293.00  2,583.00  5,233.00  4,421.00
# 1  4,387.00  5,026.00  4,055.00  2,782.00  4,578.00  4,993.00  2,859.00
# 2  5,027.00  4,078.00  3,858.00  1,927.00  3,527.00  4,179.00  1,571.00
# 3  3,826.00  4,932.00  1,710.00  3,221.00  3,381.00  1,313.00  1,765.00
# 4  1,413.00  2,091.00  3,270.00  3,346.00  2,080.00  1,539.00  2,630.00
#
#    DECEMBER
# 0  4,071.00
# 1  4,853.00
# 2  5,551.00
# 3  1,214.00
# 4  1,697.00

# %%
# You can display the last five records using the tail() method.
print (sales.tail())
# Out:
#     SALES_ID SALES_BY_REGION   JANUARY  FEBRUARY     MARCH     APRIL  \
# 93        29             FUJ  2,492.00  1,833.00  2,982.00  4,292.00
# 94        30             AJM  2,832.00  5,978.00  1,684.00  1,550.00
# 95        30             FUJ  3,402.00  5,283.00  2,229.00  3,758.00
# 96        30             AJM  2,028.00  2,006.00  5,120.00  5,959.00
# 97        30             FUJ  5,549.00  1,302.00  1,929.00  2,822.00
#
#          MAY      JUNE      JULY    AUGUST SEPTEMBER   OCTOBER  NOVEMBER  \
# 93  5,540.00  5,847.00       909  2,339.00  4,868.00  5,207.00  5,938.00
# 94  1,194.00  3,737.00  5,779.00  4,441.00  1,213.00  3,711.00  5,384.00
# 95  1,427.00  1,057.00  5,277.00  5,231.00  3,909.00  4,345.00  5,287.00
# 96  3,127.00  3,962.00  4,780.00  3,200.00  1,836.00  2,623.00  1,607.00
# 97  5,379.00  1,243.00  3,075.00  4,358.00  5,106.00  2,322.00  2,409.00
#
#     DECEMBER
# 93  1,793.00
# 94  1,293.00
# 95  2,638.00
# 96  2,371.00
# 97  1,069.00

# %%
# you can use the nrows attribute to control the number of rows you want to read.
import pandas as pd
salesNrows = pd.read_csv("Sales.csv", nrows=4)
salesNrows
# Out:
#    SALES_ID SALES_BY_REGION   JANUARY  FEBRUARY         MARCH     APRIL  \
# 0         1             AUH  3,469.00      n.a.  not avilable  3,642.00
# 1         1             SHJ  5,840.00  5,270.00      4,114.00  5,605.00
# 2         1              -1  2,967.00  2,425.00      5,353.00      n.a.
# 3         2             AUH  1,328.00        -1      1,574.00  2,343.00
#
#         MAY      JUNE      JULY    AUGUST SEPTEMBER   OCTOBER  NOVEMBER  \
# 0  5,803.00  5,662.00  1,896.00  2,293.00  2,583.00  5,233.00  4,421.00
# 1  4,387.00  5,026.00  4,055.00  2,782.00  4,578.00  4,993.00  2,859.00
# 2  5,027.00  4,078.00  3,858.00  1,927.00  3,527.00  4,179.00  1,571.00
# 3  3,826.00  4,932.00  1,710.00  3,221.00  3,381.00  1,313.00  1,765.00
#
#    DECEMBER
# 0  4,071.00
# 1  4,853.00
# 2  5,551.00
# 3  1,214.00

# %% [markdown]
# ### Renaming Column Labels

# %%
# you can read specific columns using a column index or label. 
salesNrows = pd.read_csv("Sales.csv", nrows=4,usecols=[0, 1, 6])
salesNrows
# Out:
#    SALES_ID SALES_BY_REGION       MAY
# 0         1             AUH  5,803.00
# 1         1             SHJ  4,387.00
# 2         1              -1  5,027.00
# 3         2             AUH  3,826.00

# %%
salesNrows = pd.read_csv("Sales.csv", nrows=4,usecols=['SALES_ID' , 'SALES_BY_REGION', 'FEBRUARY', 'MARCH'])
salesNrows
# Out:
#    SALES_ID SALES_BY_REGION  FEBRUARY         MARCH
# 0         1             AUH      n.a.  not avilable
# 1         1             SHJ  5,270.00      4,114.00
# 2         1              -1  2,425.00      5,353.00
# 3         2             AUH        -1      1,574.00

# %%
# Renaming Column Labels
salesNrows.rename(columns={"SALES_ID":'ID',"SALES_BY_REGION":'REGION'}, inplace=True)
salesNrows
# Out:
#    ID REGION   JANUARY  FEBRUARY         MARCH     APRIL       MAY      JUNE  \
# 0   1    AUH  3,469.00      n.a.  not avilable  3,642.00  5,803.00  5,662.00
# 1   1    SHJ  5,840.00  5,270.00      4,114.00  5,605.00  4,387.00  5,026.00
# 2   1     -1  2,967.00  2,425.00      5,353.00      n.a.  5,027.00  4,078.00
# 3   2    AUH  1,328.00        -1      1,574.00  2,343.00  3,826.00  4,932.00
#
#        JULY    AUGUST SEPTEMBER   OCTOBER  NOVEMBER  DECEMBER
# 0  1,896.00  2,293.00  2,583.00  5,233.00  4,421.00  4,071.00
# 1  4,055.00  2,782.00  4,578.00  4,993.00  2,859.00  4,853.00
# 2  3,858.00  1,927.00  3,527.00  4,179.00  1,571.00  5,551.00
# 3  1,710.00  3,221.00  3,381.00  1,313.00  1,765.00  1,214.00

# %%
# Finding Unique Values in Columns
print (len(salesNrows['JANUARY'].unique()))
print (len(salesNrows['REGION'].unique()))
print (salesNrows['JANUARY'].unique())
# Out:
# 4
# 3
# ['3,469.00' '5,840.00' '2,967.00' '1,328.00']

# %% [markdown]
# ### Automatically Replacing Matched Cases with NaN

# %%
import pandas as pd
sales = pd.read_csv("Sales.csv", nrows=7, na_values=["n.a.", "not avilable"])
mydata = sales.head(7)
mydata
# Out:
#    SALES_ID SALES_BY_REGION   JANUARY  FEBRUARY     MARCH     APRIL       MAY  \
# 0         1             AUH  3,469.00       NaN       NaN  3,642.00  5,803.00
# 1         1             SHJ  5,840.00  5,270.00  4,114.00  5,605.00  4,387.00
# 2         1              -1  2,967.00  2,425.00  5,353.00       NaN  5,027.00
# 3         2             AUH  1,328.00        -1  1,574.00  2,343.00  3,826.00
# 4         3             SHJ  2,473.00  1,421.00  3,606.00  1,314.00  1,413.00
# 5         3             NaN       NaN       956  1,297.00  1,984.00  2,744.00
# 6         3             AUH  2,634.00  2,143.00  3,698.00  5,767.00  2,782.00
#
#        JUNE      JULY    AUGUST SEPTEMBER   OCTOBER  NOVEMBER  DECEMBER
# 0  5,662.00  1,896.00  2,293.00  2,583.00  5,233.00  4,421.00  4,071.00
# 1  5,026.00  4,055.00  2,782.00  4,578.00  4,993.00  2,859.00  4,853.00
# 2  4,078.00  3,858.00  1,927.00  3,527.00  4,179.00  1,571.00  5,551.00
# 3  4,932.00  1,710.00  3,221.00  3,381.00  1,313.00  1,765.00  1,214.00
# 4  2,091.00  3,270.00  3,346.00  2,080.00  1,539.00  2,630.00  1,697.00
# 5  5,793.00  2,261.00  5,607.00  2,437.00  4,328.00  3,317.00  5,390.00
# 6  4,444.00  5,036.00  4,805.00  5,792.00  5,256.00  4,096.00  3,170.00

# %%
import pandas as pd
sales = pd.read_csv("Sales.csv", nrows=7, na_values=["n.a.", "not avilable", -1])
mydata = sales.head(7)
mydata
# Out:
#    SALES_ID SALES_BY_REGION   JANUARY  FEBRUARY     MARCH     APRIL       MAY  \
# 0         1             AUH  3,469.00       NaN       NaN  3,642.00  5,803.00
# 1         1             SHJ  5,840.00  5,270.00  4,114.00  5,605.00  4,387.00
# 2         1             NaN  2,967.00  2,425.00  5,353.00       NaN  5,027.00
# 3         2             AUH  1,328.00       NaN  1,574.00  2,343.00  3,826.00
# 4         3             SHJ  2,473.00  1,421.00  3,606.00  1,314.00  1,413.00
# 5         3             NaN       NaN       956  1,297.00  1,984.00  2,744.00
# 6         3             AUH  2,634.00  2,143.00  3,698.00  5,767.00  2,782.00
#
#        JUNE      JULY    AUGUST SEPTEMBER   OCTOBER  NOVEMBER  DECEMBER
# 0  5,662.00  1,896.00  2,293.00  2,583.00  5,233.00  4,421.00  4,071.00
# 1  5,026.00  4,055.00  2,782.00  4,578.00  4,993.00  2,859.00  4,853.00
# 2  4,078.00  3,858.00  1,927.00  3,527.00  4,179.00  1,571.00  5,551.00
# 3  4,932.00  1,710.00  3,221.00  3,381.00  1,313.00  1,765.00  1,214.00
# 4  2,091.00  3,270.00  3,346.00  2,080.00  1,539.00  2,630.00  1,697.00
# 5  5,793.00  2,261.00  5,607.00  2,437.00  4,328.00  3,317.00  5,390.00
# 6  4,444.00  5,036.00  4,805.00  5,792.00  5,256.00  4,096.00  3,170.00

# %%
sales = pd.read_csv("Sales.csv", na_values = {"SALES_BY_REGION": ["n.a.", "not avilabl"],"JANUARY": ["n.a.", "not avilable", -1],"FEBRUARY": ["n.a.", "not avilable", -1]})
sales.head(20)
# Out:
#     SALES_ID SALES_BY_REGION   JANUARY  FEBRUARY         MARCH     APRIL  \
# 0          1             AUH  3,469.00       NaN  not avilable  3,642.00
# 1          1             SHJ  5,840.00  5,270.00      4,114.00  5,605.00
# 2          1              -1  2,967.00  2,425.00      5,353.00      n.a.
# 3          2             AUH  1,328.00       NaN      1,574.00  2,343.00
# 4          3             SHJ  2,473.00  1,421.00      3,606.00  1,314.00
# 5          3    not avilable       NaN       956      1,297.00  1,984.00
# 6          3             AUH  2,634.00  2,143.00      3,698.00  5,767.00
# 7          4             AJM  4,673.00  1,322.00      2,615.00  3,423.00
# 8          4             RAK  4,862.00       947      3,400.00  3,913.00
# 9          4             RAK  5,829.00  1,802.00      2,345.00  5,131.00
# 10         4              -1  4,870.00  4,645.00      5,521.00  4,824.00
# 11         5             FUJ  2,152.00  3,064.00      3,981.00  2,958.00
# 12         5             AJM  5,584.00  1,103.00      2,838.00  3,520.00
# 13         5             DXB  4,258.00  1,397.00      3,824.00  4,715.00
# 14         5             SHJ  1,738.00  5,212.00      4,647.00  3,637.00
# 15         5             RAK  5,847.00  5,635.00      2,110.00       944
# 16         6             DXB  2,223.00  2,054.00      3,339.00  4,368.00
# 17         7             FUJ  5,564.00  1,972.00      3,522.00  2,779.00
# 18         7             FUJ  1,119.00  1,666.00      3,257.00  1,188.00
# 19         7             SHJ  1,723.00  1,196.00      2,044.00       925
#
#          MAY      JUNE      JULY    AUGUST SEPTEMBER   OCTOBER  NOVEMBER  \
# 0   5,803.00  5,662.00  1,896.00  2,293.00  2,583.00  5,233.00  4,421.00
# 1   4,387.00  5,026.00  4,055.00  2,782.00  4,578.00  4,993.00  2,859.00
# 2   5,027.00  4,078.00  3,858.00  1,927.00  3,527.00  4,179.00  1,571.00
# 3   3,826.00  4,932.00  1,710.00  3,221.00  3,381.00  1,313.00  1,765.00
# 4   1,413.00  2,091.00  3,270.00  3,346.00  2,080.00  1,539.00  2,630.00
# 5   2,744.00  5,793.00  2,261.00  5,607.00  2,437.00  4,328.00  3,317.00
# 6   2,782.00  4,444.00  5,036.00  4,805.00  5,792.00  5,256.00  4,096.00
# 7   5,694.00  3,544.00  2,093.00  2,676.00  5,979.00  5,481.00  4,786.00
# 8   5,654.00  2,504.00  1,922.00  1,577.00  2,766.00  2,318.00  5,906.00
# 9   3,662.00  1,323.00  3,214.00  1,150.00  1,191.00  1,328.00  3,766.00
# 10  3,899.00  1,118.00  3,665.00  5,241.00  2,433.00  5,215.00  1,858.00
# 11  3,794.00  5,453.00  3,324.00      n.a.  1,516.00  5,640.00  1,301.00
# 12  2,250.00  1,435.00  3,035.00  4,572.00  5,450.00  2,374.00  1,549.00
# 13  3,150.00  5,572.00       968  1,014.00  2,784.00  5,913.00       969
# 14  4,616.00  4,651.00  2,298.00  3,097.00  4,239.00  3,001.00  2,457.00
# 15  2,597.00  2,381.00  2,094.00  5,849.00  2,393.00  3,246.00  5,784.00
# 16  4,539.00  5,852.00  2,304.00  1,841.00  4,616.00  4,180.00  2,503.00
# 17  1,371.00  5,419.00  1,398.00  4,277.00  5,467.00  4,831.00  1,507.00
# 18  5,301.00  1,362.00  3,452.00       912  4,756.00       962  3,618.00
# 19  2,973.00  1,581.00  1,812.00  4,429.00  1,230.00  5,813.00  2,119.00
#
#     DECEMBER
# 0   4,071.00
# 1   4,853.00
# 2   5,551.00
# 3   1,214.00
# 4   1,697.00
# 5   5,390.00
# 6   3,170.00
# 7   1,637.00
# 8   5,477.00
# 9   2,050.00
# 10  4,667.00
# 11  5,513.00
# 12  4,885.00
# 13  4,153.00
# 14       975
# 15  1,486.00
# 16  4,211.00
# 17  3,749.00
# 18  1,351.00
# 19  3,105.00

# %%
# Defining and Calling Functions for Data Cleaning

def CleanData_Sales(cell):
    if (cell=="n.a." or cell=="-1" or cell=="not avilable"):
        return 0
    return cell
def CleanData_REGION(cell):
    if (cell=="n.a." or cell=="-1" or cell=="not avilable"):
        return 'AbuDhabi'
    return cell

# %%
sales = pd.read_csv("Sales.csv", nrows=7, converters={"SALES_BY_REGION": CleanData_REGION,"JANUARY": CleanData_Sales,"FEBRUARY": CleanData_Sales,"APRIL": CleanData_Sales,})
sales.head(20)
# Out:
#    SALES_ID SALES_BY_REGION   JANUARY  FEBRUARY         MARCH     APRIL  \
# 0         1             AUH  3,469.00         0  not avilable  3,642.00
# 1         1             SHJ  5,840.00  5,270.00      4,114.00  5,605.00
# 2         1        AbuDhabi  2,967.00  2,425.00      5,353.00         0
# 3         2             AUH  1,328.00         0      1,574.00  2,343.00
# 4         3             SHJ  2,473.00  1,421.00      3,606.00  1,314.00
# 5         3        AbuDhabi         0       956      1,297.00  1,984.00
# 6         3             AUH  2,634.00  2,143.00      3,698.00  5,767.00
#
#         MAY      JUNE      JULY    AUGUST SEPTEMBER   OCTOBER  NOVEMBER  \
# 0  5,803.00  5,662.00  1,896.00  2,293.00  2,583.00  5,233.00  4,421.00
# 1  4,387.00  5,026.00  4,055.00  2,782.00  4,578.00  4,993.00  2,859.00
# 2  5,027.00  4,078.00  3,858.00  1,927.00  3,527.00  4,179.00  1,571.00
# 3  3,826.00  4,932.00  1,710.00  3,221.00  3,381.00  1,313.00  1,765.00
# 4  1,413.00  2,091.00  3,270.00  3,346.00  2,080.00  1,539.00  2,630.00
# 5  2,744.00  5,793.00  2,261.00  5,607.00  2,437.00  4,328.00  3,317.00
# 6  2,782.00  4,444.00  5,036.00  4,805.00  5,792.00  5,256.00  4,096.00
#
#    DECEMBER
# 0  4,071.00
# 1  4,853.00
# 2  5,551.00
# 3  1,214.00
# 4  1,697.00
# 5  5,390.00
# 6  3,170.00
